# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
TRAIN_DATADIR = '/Volumes/b/Galvanize/DS-RFT4/capstones-RFT4/datasets/covid_pneumonia/712865_1242442_bundle_archive/train'
TEST_DATADIR = '/Volumes/b/Galvanize/DS-RFT4/capstones-RFT4/datasets/covid_pneumonia/712865_1242442_bundle_archive/test'

# %%
category = 'COVID-19'
path = os.path.join(TRAIN_DATADIR, category)
imgs = os.listdir(path)

cov_train_len = len(imgs)

# %%
category = 'Pneumonia'
path = os.path.join(TRAIN_DATADIR, category)
imgs = os.listdir(path)

pneum_train_len = len(imgs)

# %%
category = 'Normal'
path = os.path.join(TRAIN_DATADIR, category)
imgs = os.listdir(path)

norm_train_len = len(imgs)

# %%
category = 'COVID-19'
path = os.path.join(TEST_DATADIR, category)
imgs = os.listdir(path)

cov_test_len = len(imgs)

# %%
category = 'Pneumonia'
path = os.path.join(TEST_DATADIR, category)
imgs = os.listdir(path)

pneum_test_len = len(imgs)

# %%
category = 'Normal'
path = os.path.join(TEST_DATADIR, category)
imgs = os.listdir(path)

norm_test_len = len(imgs)

# %%
print('cov train images:', cov_train_len)
print('pneum train images:', pneum_train_len)
print('norm train images:', norm_train_len)
print()
print('cov test images:', cov_test_len)
print('pneum test images:', pneum_test_len)
print('norm test images:', norm_test_len)
# Out:
# cov train images: 473
# pneum train images: 5458
# norm train images: 7966
#
# cov test images: 100
# pneum test images: 100
# norm test images: 100

# %%
plt.style.use('fivethirtyeight')

# %%
X_train = ['COVID-19', 'Pneumonia', 'Normal']
y_train = [cov_train_len, pneum_train_len, norm_train_len]

X_test = ['COVID-19', 'Pneumonia', 'Normal']
y_test = [cov_test_len, pneum_test_len, norm_test_len]

# %%
plt.bar(X_train, y_train)
plt.title('Training Images')
plt.xlabel('Class')
plt.ylabel('Images')
plt.tight_layout()
plt.savefig('images/training_images_1.png')
;
# Out:
# ''

# %%
plt.bar(X_test, y_test)
plt.title('Testing Images')
plt.xlabel('Class')
plt.ylabel('Images')
plt.tight_layout()
plt.savefig('images/testing_images_1.png')
;
# Out:
# ''

# %%
TRAIN_DATADIR = '/Volumes/b/Galvanize/DS-RFT4/capstones-RFT4/datasets/covid_pneumonia/chest_xray/train'
TEST_DATADIR = '/Volumes/b/Galvanize/DS-RFT4/capstones-RFT4/datasets/covid_pneumonia/chest_xray/test'
VAL_DATADIR = '/Volumes/b/Galvanize/DS-RFT4/capstones-RFT4/datasets/covid_pneumonia/chest_xray/val'

# %%
category = 'PNEUMONIA'
path = os.path.join(TRAIN_DATADIR, category)
imgs = os.listdir(path)

pneum_train_len = len(imgs)

# %%
category = 'PNEUMONIA'
path = os.path.join(TEST_DATADIR, category)
imgs = os.listdir(path)

pneum_test_len = len(imgs)

# %%
category = 'PNEUMONIA'
path = os.path.join(VAL_DATADIR, category)
imgs = os.listdir(path)

pneum_val_len = len(imgs)

# %%
category = 'NORMAL'
path = os.path.join(TRAIN_DATADIR, category)
imgs = os.listdir(path)

norm_train_len = len(imgs)

# %%
category = 'NORMAL'
path = os.path.join(TEST_DATADIR, category)
imgs = os.listdir(path)

norm_test_len = len(imgs)

# %%
category = 'NORMAL'
path = os.path.join(VAL_DATADIR, category)
imgs = os.listdir(path)

norm_val_len = len(imgs)

# %%
print('pneum train images:', pneum_train_len)
print('norm train images:', norm_train_len)
print()
print('pneum test images:', pneum_test_len)
print('norm test images:', norm_test_len)
# Out:
# pneum train images: 3875
# norm train images: 1341
#
# pneum test images: 390
# norm test images: 234

# %%
X_train = ['Pneumonia', 'Normal']
y_train = [pneum_train_len, norm_train_len]

X_test = ['Pneumonia', 'Normal']
y_test = [pneum_test_len, norm_test_len]

X_val = ['Pneumonia', 'Normal']
y_val = [pneum_val_len, norm_val_len]

# %%
plt.bar(X_train, y_train)
plt.title('Training Images')
plt.xlabel('Class')
plt.ylabel('Images')
plt.tight_layout()
plt.savefig('images/training_images.png')


;
# Out:
# ''

# %%
plt.bar(X_test, y_test)
plt.title('Validation Images')
plt.xlabel('Class')
plt.ylabel('Images')
plt.tight_layout()
plt.savefig('images/validation_images.png')
;
# Out:
# ''

# %%
plt.bar(X_val, y_val)
plt.title('Testing Images')
plt.xlabel('Class')
plt.ylabel('Images')
plt.tight_layout()
plt.savefig('images/testing_images.png')
;
# Out:
# ''
